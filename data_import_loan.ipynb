# %%
import kaggle
kaggle.api.authenticate()


kaggle.api.dataset_download_files(
        'abhishekmishra08/loan-approval-datasets',  # Replace with the actual dataset name
        path='./', # Replace with the desired path
        unzip=True  # Set to True to unzip the downloaded archive
    )
# Out:
# Dataset URL: https://www.kaggle.com/datasets/abhishekmishra08/loan-approval-datasets
